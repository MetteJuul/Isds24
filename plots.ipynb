# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By
import requests
from bs4 import BeautifulSoup
import time
import pandas as pd
from pathlib import Path
from zipfile import ZipFile
import matplotlib.pyplot as plt
import pprint
import numpy as np
import seaborn as sns

# %%
# Path to the CSV file
csv_file = './cleaned_merged_course_data.csv'

# Load the CSV file into a DataFrame
df = pd.read_csv(csv_file)

# %%
# Convert "Eksamensgennemsnit" to a numeric type
df['Eksamensgennemsnit'] = pd.to_numeric(df['Eksamensgennemsnit'].str.replace(',', '.'), errors='coerce')

# Ensure "Fremmødte" is numeric (if it isn't already)
df['Fremmødte'] = pd.to_numeric(df['Fremmødte'], errors='coerce')

fig, ax = plt.subplots(figsize=(10,5))
sns.regplot(y='Eksamensgennemsnit', x='Fremmødte', data=df)
# Out:
# <Axes: xlabel='Fremmødte', ylabel='Eksamensgennemsnit'>

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Path to the CSV file
csv_file = './cleaned_with_weight_2.csv'

# Load the CSV file into a DataFrame
df = pd.read_csv(csv_file)

# Ensure "Fremmødte" is numeric
df['Fremmødte'] = pd.to_numeric(df['Fremmødte'], errors='coerce')

# Create the plot
fig, ax = plt.subplots(figsize=(10, 5))
sns.regplot(y='WMA', x='Fremmødte', data=df, ax=ax)

# Add labels and title for clarity
ax.set_xlabel('Fremmødte')
ax.set_ylabel('WMA')
ax.set_title('Trend Line of WMA vs. Fremmødte')

# Optionally, add gridlines
ax.grid(True)

# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Path to the CSV file
csv_file = './cleaned_with_weight.csv'

# Load the CSV file into a DataFrame
df = pd.read_csv(csv_file)

# Ensure "Fremmødte" is numeric
df['Fremmødte'] = pd.to_numeric(df['Fremmødte'], errors='coerce')

# Create the plot
fig, ax = plt.subplots(figsize=(10, 5))
sns.regplot(y='WMA', x='Fremmødte', data=df, ax=ax)

# Add labels and title for clarity
ax.set_xlabel('Fremmødte')
ax.set_ylabel('WMA')
ax.set_title('Trend Line of WMA vs. Fremmødte')

# Optionally, add gridlines
ax.grid(True)

# Display the plot
plt.show()
